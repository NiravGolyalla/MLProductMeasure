# %%
import pandas as pd

# %%
cos_df = pd.read_csv('data/Cosmetic_products_sales.csv')

# %%
cos_df.set_index('Date').aggregate('sum').reset_index()
# Out:
#                    index                                                  0
# 0              ParentSKU  F0033F0033F0033F0033F0033F0033F0033F0033F0033F...
# 1                Site Id  AHMEDABADAHMEDABADAHMEDABADAHMEDABADAHMEDABADA...
# 2                   Year                                           70537431
# 3                  Month                                             230415
# 4       Category Name ID                                             197479
# 5                   Unit  NONONONONONONONONONONONONONONONONONONONONONONO...
# 6                    Qty                                        22651928.08
# 7                  Price                                            5963324
# 8   Net Sales calculated                                         2383731786
# 9          Cash Discount                                              28942
# 10    Amount to Customer                                         2405269308
# ...

# %%
cos_df.set_index(['Year','Month'])
# Out:
#            ParentSKU     Site Id  Category Name ID Unit     Qty  Price  \
# Year Month
# 2017 4         F0033   AHMEDABAD                 0   NO  1621.0     54
#      5         F0033   AHMEDABAD                 0   NO   651.0     51
#      6         F0033   AHMEDABAD                 0   NO   457.0     46
#      7         F0033   AHMEDABAD                 0   NO  1985.0     41
#      8         F0033   AHMEDABAD                 0   NO     6.0     38
# ...              ...         ...               ...  ...     ...    ...
# 2019 9         T0270  VIJAYAWADA                 1   NO  1008.0     40
#      10        T0270  VIJAYAWADA                 1   NO  1179.0     40
#      12        T0270  VIJAYAWADA                 1   NO    81.0     40
# 2020 1         T0270  VIJAYAWADA                 1   NO   580.0     40
#      2         T0270  VIJAYAWADA                 1   NO   180.0     40
#
#             Net Sales calculated  Cash Discount  Amount to Customer   MRP  \
# Year Month
# ...

# %%
cos_df.columns
# Out:
# Index(['ParentSKU', 'Site Id', 'Year', 'Month', 'Category Name ID', 'Unit',
#        'Qty', 'Price', 'Net Sales calculated', 'Cash Discount',
#        'Amount to Customer', 'MRP', 'Pack Size', 'Pack Unit Id', 'State',
#        'Zone', 'Master Category', 'Size', 'Rank', 'Date'],
#       dtype='object')
