# %%
import pandas as pd

# %%
cos_df = pd.read_csv('data/Cosmetic_products_sales.csv')

# %%
cos_df.drop[].set_index(['Year','Month']).aggregate('sum').reset_index()
# Out:
#                    index                                                  0
# 0              ParentSKU  F0033F0033F0033F0033F0033F0033F0033F0033F0033F...
# 1                Site Id  AHMEDABADAHMEDABADAHMEDABADAHMEDABADAHMEDABADA...
# 2       Category Name ID                                             197479
# 3                   Unit  NONONONONONONONONONONONONONONONONONONONONONONO...
# 4                    Qty                                        22651928.08
# 5                  Price                                            5963324
# 6   Net Sales calculated                                         2383731786
# 7          Cash Discount                                              28942
# 8     Amount to Customer                                         2405269308
# 9                    MRP                                     9362687.356484
# 10             Pack Size                                     3689522.191614
# ...
